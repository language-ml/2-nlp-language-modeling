# %%
from gensim.models.keyedvectors import KeyedVectors

word_vectors_en = KeyedVectors.load_word2vec_format('embedding/wiki-news-300d-1M.vec')

# %%
word_vectors_en.most_similar(positive=['king','woman'],negative=['man'])
# Out:
# [('queen', 0.7515910863876343),
#  ('monarch', 0.6741327047348022),
#  ('princess', 0.6713886260986328),
#  ('kings', 0.669899046421051),
#  ('kingdom', 0.5971317887306213),
#  ('royal', 0.592106282711029),
#  ('uncrowned', 0.5911506414413452),
#  ('prince', 0.5909028053283691),
#  ('lady', 0.5904011130332947),
#  ('monarchs', 0.5884358286857605)]

# %%
word_vectors_fa = KeyedVectors.load_word2vec_format('embedding/cc.fa.300.vec')

# %%
word_vectors_en.most_similar(positive=['شاه','زن'],negative=['مرد'], topn=100)
# Out:
# [('نو', 0.8407261967658997),
#  ('رخ', 0.8289567232131958),
#  ('بزرگ', 0.825718104839325),
#  ('جمهوری', 0.8256292939186096),
#  ('بخش', 0.8235875368118286),
#  ('استاد', 0.822256863117218),
#  ('پور', 0.8216066360473633),
#  ('شاعر', 0.819129467010498),
#  ('امیر', 0.8180691003799438),
#  ('دانش', 0.818019688129425),
#  ('شناسی', 0.8174564242362976),
#  ('نژاد', 0.816980242729187),
#  ('زاده', 0.8165879249572754),
#  ('سر', 0.8143221735954285),
#  ('دولت', 0.8138113021850586),
#  ('نامه', 0.8137931227684021),
#  ('حکیم', 0.8126270771026611),
#  ('محل', 0.8119232058525085),
#  ('الدین', 0.8114858269691467),
#  ('فردوسی', 0.8083471059799194),
#  ('خانه', 0.8081957101821899),
#  ('چهار', 0.8081780076026917),
#  ('کوه', 0.8079643249511719),
#  ('آباد', 0.8073756098747253),
#  ('شیر', 0.8069671988487244),
#  ('سی', 0.8064829111099243),
#  ('پارسی', 0.8060727119445801),
#  ('امام', 0.8054182529449463),
#  ('تاج', 0.8043192625045776),
#  ('خدا', 0.8033311367034912),
# ...
